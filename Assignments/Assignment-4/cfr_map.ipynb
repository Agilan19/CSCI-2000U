# %%
#Agilan Ampigaipathar
#100553054

#Plot inline
# %pylab inline

#Imports 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from JSAnimation.IPython_display import display_animation

import urllib
from mpl_toolkits.basemap import Basemap

import csv

Category = []
Lat = []
Long = []
Cases = []

#Make a 10 x 10 figure to plot the results in.
plt.figure(figsize=(10, 10))

#Use the earthquake program template to create the earth plot
earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

#Open the csv file and gather the required data row by row for each
#specific column and append them into their respective arrays
with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))

#Convert the strings into floating point values that can be plotted.
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))

k = 0

#Look for all data corresponding to Measles for the Measles plot.
for i in range (k, len(Category)):
    if (Category[k] == 'Measles'):
        x, y = earth(Long[k], Lat[k])
        
        #Make if statements for the markersize to increase based on the 
        #amount of cases
        if (Cases[k] >= 0 and Cases[k] < 5000):
            earth.plot(x, y, 'ro',markersize=5,alpha=.5)
            
        elif (Cases[k] >= 5000 and Cases[k] < 10000):
            earth.plot(x, y, 'ro',markersize=10,alpha=.5)
            
        elif (Cases[k] >= 10000 and Cases[k] < 15000):
            earth.plot(x, y, 'ro',markersize=15,alpha=.5)
            
        elif (Cases[k] >= 15000 and Cases[k] < 20000):
            earth.plot(x, y, 'ro',markersize=20,alpha=.5)
            
        elif (Cases[k] >= 20000 and Cases[k] < 25000):
            earth.plot(x, y, 'ro',markersize=25,alpha=.5)
            
        elif (Cases[k] >= 25000 and Cases[k] < 30000):
            earth.plot(x, y, 'ro',markersize=30,alpha=.5)
            
        elif (Cases[k] >= 30000 and Cases[k] < 35000):
            earth.plot(x, y, 'ro',markersize=35,alpha=.5)
            
        elif (Cases[k] >= 35000 and Cases[k] < 40000):
            earth.plot(x, y, 'ro',markersize=40,alpha=.5)
            
        elif (Cases[k] >= 40000 and Cases[k] < 45000):
            earth.plot(x, y, 'ro',markersize=45,alpha=.5)
            
        elif (Cases[k] >= 45000 and Cases[k] < 50000):
            earth.plot(x, y, 'ro',markersize=50,alpha=.5)
            
        elif (Cases[k] >= 50000 and Cases[k] < 55000):
            earth.plot(x, y, 'ro',markersize=55,alpha=.5)
            
        elif (Cases[k] >= 55000 and Cases[k] < 60000):
            earth.plot(x, y, 'ro',markersize=60,alpha=.5)
            
        elif (Cases[k] >= 60000 and Cases[k] < 65000):
            earth.plot(x, y, 'ro',markersize=65,alpha=.5)
            
        elif (Cases[k] >= 65000 and Cases[k] < 70000):
            earth.plot(x, y, 'ro',markersize=70,alpha=.5)
            
        elif (Cases[k] >= 70000 and Cases[k] < 75000):
            earth.plot(x, y, 'ro',markersize=75,alpha=.5)
            
        elif (Cases[k] >= 75000 and Cases[k] < 80000):
            earth.plot(x, y, 'ro',markersize=80,alpha=.5)
            
        elif (Cases[k] >= 80000 and Cases[k] < 85000):
            earth.plot(x, y, 'ro',markersize=85,alpha=.5)
            
        elif (Cases[k] >= 85000 and Cases[k] < 90000):
            earth.plot(x, y, 'ro',markersize=90,alpha=.5)
            
        elif (Cases[k] >= 90000 and Cases[k] < 95000):
            earth.plot(x, y, 'ro',markersize=95,alpha=.5)
            
        elif (Cases[k] >= 95000 and Cases[k] < 100000):
            earth.plot(x, y, 'ro',markersize=100,alpha=.5)
            
        elif (Cases[k] >= 100000 and Cases[k] < 105000):
            earth.plot(x, y, 'ro',markersize=105,alpha=.5)
            
        elif (Cases[k] >= 105000 and Cases[k] < 110000):
            earth.plot(x, y, 'ro',markersize=110,alpha=.5)
            
        elif (Cases[k] >= 110000 and Cases[k] < 115000):
            earth.plot(x, y, 'ro',markersize=115,alpha=.5)
            
        elif (Cases[k] >= 115000 and Cases[k] < 120000):
            earth.plot(x, y, 'ro',markersize=120,alpha=.5)
            
        elif (Cases[k] >= 120000 and Cases[k] < 125000):
            earth.plot(x, y, 'ro',markersize=125,alpha=.5)
            
        elif (Cases[k] >= 125000 and Cases[k] < 130000):
            earth.plot(x, y, 'ro',markersize=130,alpha=.5)
            
        elif (Cases[k] >= 130000 and Cases[k] < 135000):
            earth.plot(x, y, 'ro',markersize=135,alpha=.5)
            
        elif (Cases[k] >= 135000 and Cases[k] < 140000):
            earth.plot(x, y, 'ro',markersize=140,alpha=.5)
    k += 1
    
plt.title("Measles outbreaks (100553054)")
plt.show()

plt.figure(figsize=(10, 10))

earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))

        
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))

l = 0

for i in range (l, len(Category)):
    if (Category[l] == 'Rubella'):
        x, y = earth(Long[l], Lat[l])
        
        if (Cases[l] >= 0 and Cases[l] < 5000):
            earth.plot(x, y, 'mo',markersize=5,alpha=.5)
            
        elif (Cases[l] >= 5000 and Cases[l] < 10000):
            earth.plot(x, y, 'mo',markersize=10,alpha=.5)
            
        elif (Cases[l] >= 10000 and Cases[l] < 15000):
            earth.plot(x, y, 'mo',markersize=15,alpha=.5)
            
        elif (Cases[l] >= 15000 and Cases[l] < 20000):
            earth.plot(x, y, 'mo',markersize=20,alpha=.5)
            
        elif (Cases[l] >= 20000 and Cases[l] < 25000):
            earth.plot(x, y, 'mo',markersize=25,alpha=.5)
            
        elif (Cases[l] >= 25000 and Cases[l] < 30000):
            earth.plot(x, y, 'mo',markersize=30,alpha=.5)
            
        elif (Cases[l] >= 30000 and Cases[l] < 35000):
            earth.plot(x, y, 'mo',markersize=35,alpha=.5)
            
        elif (Cases[l] >= 35000 and Cases[l] < 40000):
            earth.plot(x, y, 'mo',markersize=40,alpha=.5)
            
        elif (Cases[l] >= 40000 and Cases[l] < 45000):
            earth.plot(x, y, 'mo',markersize=45,alpha=.5)
            
        elif (Cases[l] >= 45000 and Cases[l] < 50000):
            earth.plot(x, y, 'mo',markersize=50,alpha=.5)
            
        elif (Cases[l] >= 50000 and Cases[l] < 55000):
            earth.plot(x, y, 'mo',markersize=55,alpha=.5)
            
        elif (Cases[l] >= 55000 and Cases[l] < 60000):
            earth.plot(x, y, 'mo',markersize=60,alpha=.5)
            
        elif (Cases[l] >= 60000 and Cases[l] < 65000):
            earth.plot(x, y, 'mo',markersize=65,alpha=.5)
            
        elif (Cases[l] >= 65000 and Cases[l] < 70000):
            earth.plot(x, y, 'mo',markersize=70,alpha=.5)
            
        elif (Cases[l] >= 70000 and Cases[l] < 75000):
            earth.plot(x, y, 'mo',markersize=75,alpha=.5)
            
        elif (Cases[l] >= 75000 and Cases[l] < 80000):
            earth.plot(x, y, 'mo',markersize=80,alpha=.5)
            
        elif (Cases[l] >= 80000 and Cases[l] < 85000):
            earth.plot(x, y, 'mo',markersize=85,alpha=.5)
            
        elif (Cases[l] >= 85000 and Cases[l] < 90000):
            earth.plot(x, y, 'mo',markersize=90,alpha=.5)
            
        elif (Cases[l] >= 90000 and Cases[l] < 95000):
            earth.plot(x, y, 'mo',markersize=95,alpha=.5)
            
        elif (Cases[l] >= 95000 and Cases[l] < 100000):
            earth.plot(x, y, 'mo',markersize=100,alpha=.5)
            
        elif (Cases[l] >= 100000 and Cases[l] < 105000):
            earth.plot(x, y, 'mo',markersize=105,alpha=.5)
            
        elif (Cases[l] >= 105000 and Cases[l] < 110000):
            earth.plot(x, y, 'mo',markersize=110,alpha=.5)
            
        elif (Cases[l] >= 110000 and Cases[l] < 115000):
            earth.plot(x, y, 'mo',markersize=115,alpha=.5)
            
        elif (Cases[l] >= 115000 and Cases[l] < 120000):
            earth.plot(x, y, 'mo',markersize=120,alpha=.5)
            
        elif (Cases[l] >= 120000 and Cases[l] < 125000):
            earth.plot(x, y, 'mo',markersize=125,alpha=.5)
            
        elif (Cases[l] >= 125000 and Cases[l] < 130000):
            earth.plot(x, y, 'mo',markersize=130,alpha=.5)
            
        elif (Cases[l] >= 130000 and Cases[l] < 135000):
            earth.plot(x, y, 'mo',markersize=135,alpha=.5)
    
        elif (Cases[l] >= 135000 and Cases[l] < 140000):
            earth.plot(x, y, 'mo',markersize=140,alpha=.5)

    l += 1      
    
plt.title("Rubella outbreaks (100553054)")
plt.show()

plt.figure(figsize=(10, 10))

earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))

        
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))

m = 0

for i in range (m, len(Category)):
    if (Category[m] == 'Mumps'):
        x, y = earth(Long[m], Lat[m])
        
        if (Cases[m] >= 0 and Cases[m] < 5000):
            earth.plot(x, y, 'go',markersize=5,alpha=.5)
            
        elif (Cases[m] >= 5000 and Cases[m] < 10000):
            earth.plot(x, y, 'go',markersize=10,alpha=.5)
            
        elif (Cases[m] >= 10000 and Cases[m] < 15000):
            earth.plot(x, y, 'go',markersize=15,alpha=.5)
            
        elif (Cases[m] >= 15000 and Cases[m] < 20000):
            earth.plot(x, y, 'go',markersize=20,alpha=.5)
            
        elif (Cases[m] >= 20000 and Cases[m] < 25000):
            earth.plot(x, y, 'go',markersize=25,alpha=.5)
            
        elif (Cases[m] >= 25000 and Cases[m] < 30000):
            earth.plot(x, y, 'go',markersize=30,alpha=.5)
            
        elif (Cases[m] >= 30000 and Cases[m] < 35000):
            earth.plot(x, y, 'go',markersize=35,alpha=.5)
            
        elif (Cases[m] >= 35000 and Cases[m] < 40000):
            earth.plot(x, y, 'go',markersize=40,alpha=.5)
            
        elif (Cases[m] >= 40000 and Cases[m] < 45000):
            earth.plot(x, y, 'go',markersize=45,alpha=.5)
            
        elif (Cases[m] >= 45000 and Cases[m] < 50000):
            earth.plot(x, y, 'go',markersize=50,alpha=.5)
            
        elif (Cases[m] >= 50000 and Cases[m] < 55000):
            earth.plot(x, y, 'go',markersize=55,alpha=.5)
            
        elif (Cases[m] >= 55000 and Cases[m] < 60000):
            earth.plot(x, y, 'go',markersize=60,alpha=.5)
            
        elif (Cases[m] >= 60000 and Cases[m] < 65000):
            earth.plot(x, y, 'go',markersize=65,alpha=.5)
            
        elif (Cases[m] >= 65000 and Cases[m] < 70000):
            earth.plot(x, y, 'go',markersize=70,alpha=.5)
            
        elif (Cases[m] >= 70000 and Cases[m] < 75000):
            earth.plot(x, y, 'go',markersize=75,alpha=.5)
            
        elif (Cases[m] >= 75000 and Cases[m] < 80000):
            earth.plot(x, y, 'go',markersize=80,alpha=.5)
            
        elif (Cases[m] >= 80000 and Cases[m] < 85000):
            earth.plot(x, y, 'go',markersize=85,alpha=.5)
            
        elif (Cases[m] >= 85000 and Cases[m] < 90000):
            earth.plot(x, y, 'go',markersize=90,alpha=.5)
            
        elif (Cases[m] >= 90000 and Cases[m] < 95000):
            earth.plot(x, y, 'go',markersize=95,alpha=.5)
            
        elif (Cases[m] >= 95000 and Cases[m] < 100000):
            earth.plot(x, y, 'go',markersize=100,alpha=.5)
            
        elif (Cases[m] >= 100000 and Cases[m] < 105000):
            earth.plot(x, y, 'go',markersize=105,alpha=.5)
            
        elif (Cases[m] >= 105000 and Cases[m] < 110000):
            earth.plot(x, y, 'go',markersize=110,alpha=.5)
            
        elif (Cases[m] >= 110000 and Cases[m] < 115000):
            earth.plot(x, y, 'go',markersize=115,alpha=.5)
            
        elif (Cases[m] >= 115000 and Cases[m] < 120000):
            earth.plot(x, y, 'go',markersize=120,alpha=.5)
            
        elif (Cases[m] >= 120000 and Cases[m] < 125000):
            earth.plot(x, y, 'go',markersize=125,alpha=.5)
            
        elif (Cases[m] >= 125000 and Cases[m] < 130000):
            earth.plot(x, y, 'go',markersize=130,alpha=.5)
            
        elif (Cases[m] >= 130000 and Cases[m] < 135000):
            earth.plot(x, y, 'go',markersize=135,alpha=.5)
    
        elif (Cases[m] >= 135000 and Cases[m] < 140000):
            earth.plot(x, y, 'go',markersize=140,alpha=.5)

    m += 1      
    
plt.title("Mumps outbreaks (100553054)")
plt.show()

plt.figure(figsize=(10, 10))

earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))

        
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))

n = 0

for i in range (n, len(Category)):
    if (Category[n] == 'Polio'):
        x, y = earth(Long[n], Lat[n])
        
        if (Cases[n] >= 0 and Cases[n] < 5000):
            earth.plot(x, y, 'bo',markersize=5,alpha=.5)
            
        elif (Cases[n] >= 5000 and Cases[n] < 10000):
            earth.plot(x, y, 'bo',markersize=10,alpha=.5)
            
        elif (Cases[n] >= 10000 and Cases[n] < 15000):
            earth.plot(x, y, 'bo',markersize=15,alpha=.5)
            
        elif (Cases[n] >= 15000 and Cases[n] < 20000):
            earth.plot(x, y, 'bo',markersize=20,alpha=.5)
            
        elif (Cases[n] >= 20000 and Cases[n] < 25000):
            earth.plot(x, y, 'bo',markersize=25,alpha=.5)
            
        elif (Cases[n] >= 25000 and Cases[n] < 30000):
            earth.plot(x, y, 'bo',markersize=30,alpha=.5)
            
        elif (Cases[n] >= 30000 and Cases[n] < 35000):
            earth.plot(x, y, 'bo',markersize=35,alpha=.5)
            
        elif (Cases[n] >= 35000 and Cases[n] < 40000):
            earth.plot(x, y, 'bo',markersize=40,alpha=.5)
            
        elif (Cases[n] >= 40000 and Cases[n] < 45000):
            earth.plot(x, y, 'bo',markersize=45,alpha=.5)
            
        elif (Cases[n] >= 45000 and Cases[n] < 50000):
            earth.plot(x, y, 'bo',markersize=50,alpha=.5)
            
        elif (Cases[n] >= 50000 and Cases[n] < 55000):
            earth.plot(x, y, 'bo',markersize=55,alpha=.5)
            
        elif (Cases[n] >= 55000 and Cases[n] < 60000):
            earth.plot(x, y, 'bo',markersize=60,alpha=.5)
            
        elif (Cases[n] >= 60000 and Cases[n] < 65000):
            earth.plot(x, y, 'bo',markersize=65,alpha=.5)
            
        elif (Cases[n] >= 65000 and Cases[n] < 70000):
            earth.plot(x, y, 'bo',markersize=70,alpha=.5)
            
        elif (Cases[n] >= 70000 and Cases[n] < 75000):
            earth.plot(x, y, 'bo',markersize=75,alpha=.5)
            
        elif (Cases[n] >= 75000 and Cases[n] < 80000):
            earth.plot(x, y, 'bo',markersize=80,alpha=.5)
            
        elif (Cases[n] >= 80000 and Cases[n] < 85000):
            earth.plot(x, y, 'bo',markersize=85,alpha=.5)
            
        elif (Cases[n] >= 85000 and Cases[n] < 90000):
            earth.plot(x, y, 'bo',markersize=90,alpha=.5)
            
        elif (Cases[n] >= 90000 and Cases[n] < 95000):
            earth.plot(x, y, 'bo',markersize=95,alpha=.5)
            
        elif (Cases[n] >= 95000 and Cases[n] < 100000):
            earth.plot(x, y, 'bo',markersize=100,alpha=.5)
            
        elif (Cases[n] >= 100000 and Cases[n] < 105000):
            earth.plot(x, y, 'bo',markersize=105,alpha=.5)
            
        elif (Cases[n] >= 105000 and Cases[n] < 110000):
            earth.plot(x, y, 'bo',markersize=110,alpha=.5)
            
        elif (Cases[n] >= 110000 and Cases[n] < 115000):
            earth.plot(x, y, 'bo',markersize=115,alpha=.5)
            
        elif (Cases[n] >= 115000 and Cases[n] < 120000):
            earth.plot(x, y, 'bo',markersize=120,alpha=.5)
            
        elif (Cases[n] >= 120000 and Cases[n] < 125000):
            earth.plot(x, y, 'bo',markersize=125,alpha=.5)
            
        elif (Cases[n] >= 125000 and Cases[n] < 130000):
            earth.plot(x, y, 'bo',markersize=130,alpha=.5)
            
        elif (Cases[n] >= 130000 and Cases[n] < 135000):
            earth.plot(x, y, 'bo',markersize=135,alpha=.5)
    
        elif (Cases[n] >= 135000 and Cases[n] < 140000):
            earth.plot(x, y, 'bo',markersize=140,alpha=.5)

    n += 1      
    
plt.title("Polio outbreaks (100553054)")
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
